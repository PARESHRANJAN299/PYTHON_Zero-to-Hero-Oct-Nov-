# %% [markdown]
# <a href="https://colab.research.google.com/github/PARESHRANJAN299/PYTHON_Zero-to-Hero-Oct-Nov-/blob/main/Session_1_Pyhton.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python Output

# %%
print('Hello World')
# Out:
# Hello World

# %%
#x()--funcation

# %%
print('Jahanath Swami')
# Out:
# Jahanath Swami

# %%
#print(Salman khan)-- Error

# %%
print('hello', 22,4.5,True, sep='/')
# Out:
# hello/22/4.5/True

# %%
print('hello', 333,5.54,True,end='-')
# Out:
# hello 333 5.54 True-

# %%
#1*10^308
print(1.7e30)
# Out:
# 1.7e+30

# %%
print(True)
print(False)
# Out:
# True
# False

# %%
#tuple
print((1,2,3,4,5,6,7))
# Out:
# (1, 2, 3, 4, 5, 6, 7)

# %%
#sets
print({1,2,3,4,5})
print(type({1,2,3,3,4,}))
# Out:
#   File "/tmp/ipython-input-121122814.py", line 4
#     print(type{'name':'paresh','ranjan'})
#                                       ^
# SyntaxError: ':' expected after dictionary key

# %%
print(type([1,2,3,4,5,5,5]))
# Out:
# <class 'list'>

# %%
print(type({'name':'paresh','name':'ranjan'}))
# Out:
# <class 'dict'>
